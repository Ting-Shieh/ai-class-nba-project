# %%
import pandas as pd

# %%
url = "https://dream19900930.pixnet.net/blog/post/27488519" # 在雲端上儲存了一份 tsv 檔案
name_mean_df = pd.read_html(url)[0]
name_mean_df.columns=name_mean_df.iloc[0,:]
name_mean_df
# Out:
# 0    縮寫      中文                      英文
# 0    縮寫      中文                      英文
# 1    GS      先發            game started
# 2   POS    守備位置                position
# 3   MIN    出賽時間                 minutes
# 4   MPG  平均每場時間        minutes per game
# 5   PTS      得分                  points
# 6   PPG  平均每場得分         points per game
# 7    FG     投籃數             field goals
# 8   FG%   投籃命中率   field goal percentage
# 9   FGA   投籃出手數     field goal attempts
# 10  FGM   投籃進球數         field goal made
# 11   3P     三分球               3-pointer
# 12  3P%  三分球命中率    3-pointer percentage
# 13  3PA  三分球出手數      3-pointer attempts
# 14  3PM  三分球進球數          3-pointer made
# 15  FT%   罰球命中率  free throws percentage
# 16  FTA   罰球出手數     free throw attempts
# 17  FTM   罰球進球數         free throw made
# 18   OR   攻進籃板球      offensive rebounds
# 19   DR   防守籃板球      defensive rebounds
# 20   RB     籃板球                rebounds
# 21  TOT   籃板球總數          total rebounds
# ...
