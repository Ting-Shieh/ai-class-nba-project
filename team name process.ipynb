# %%
import pandas as pd

# %%
games_df=pd.read_csv('./data/games.csv')
games_details_df=pd.read_csv('./data/games_details.csv')
players_df=pd.read_csv('./data/players.csv')
ranking_df=pd.read_csv('./data/ranking.csv')
teams_df=pd.read_csv('./data/teams.csv')

# %%
games_df[:5]
# Out:
#   GAME_DATE_EST   GAME_ID GAME_STATUS_TEXT  HOME_TEAM_ID  VISITOR_TEAM_ID  \
# 0    2020-03-01  21900895            Final    1610612766       1610612749
# 1    2020-03-01  21900896            Final    1610612750       1610612742
# 2    2020-03-01  21900897            Final    1610612746       1610612755
# 3    2020-03-01  21900898            Final    1610612743       1610612761
# 4    2020-03-01  21900899            Final    1610612758       1610612765
#
#    SEASON  TEAM_ID_home  PTS_home  FG_PCT_home  FT_PCT_home  ...  AST_home  \
# 0    2019    1610612766      85.0        0.354        0.900  ...      22.0
# 1    2019    1610612750      91.0        0.364        0.400  ...      19.0
# 2    2019    1610612746     136.0        0.592        0.805  ...      25.0
# 3    2019    1610612743     133.0        0.566        0.700  ...      38.0
# 4    2019    1610612758     106.0        0.407        0.885  ...      18.0
#
# ...

# %%
games_details_df[:5]
# Out:
#     GAME_ID     TEAM_ID TEAM_ABBREVIATION  TEAM_CITY  PLAYER_ID  \
# 0  21900895  1610612749               MIL  Milwaukee     202083
# 1  21900895  1610612749               MIL  Milwaukee     203507
# 2  21900895  1610612749               MIL  Milwaukee     201572
# 3  21900895  1610612749               MIL  Milwaukee    1628978
# 4  21900895  1610612749               MIL  Milwaukee     202339
#
#              PLAYER_NAME START_POSITION COMMENT    MIN   FGM  ...  OREB  DREB  \
# 0        Wesley Matthews              F     NaN  27:08   3.0  ...   4.0   4.0
# 1  Giannis Antetokounmpo              F     NaN  34:55  17.0  ...   2.0  18.0
# 2            Brook Lopez              C     NaN  26:25   4.0  ...   2.0   5.0
# 3       Donte DiVincenzo              G     NaN  27:35   1.0  ...   1.0   6.0
# 4           Eric Bledsoe              G     NaN  22:17   2.0  ...   1.0   0.0
#
#     REB  AST  STL  BLK   TO   PF   PTS  PLUS_MINUS
# 0   8.0  2.0  2.0  0.0  0.0  0.0   8.0        11.0
# ...

# %%
players_df[:5]
# Out:
#         PLAYER_NAME     TEAM_ID  PLAYER_ID  SEASON
# 0     Royce O'Neale  1610612762    1626220    2019
# 1  Bojan Bogdanovic  1610612762     202711    2019
# 2       Rudy Gobert  1610612762     203497    2019
# 3  Donovan Mitchell  1610612762    1628378    2019
# 4       Mike Conley  1610612762     201144    2019

# %%
ranking_df[:5]
# Out:
#       TEAM_ID  LEAGUE_ID  SEASON_ID STANDINGSDATE CONFERENCE         TEAM   G  \
# 0  1610612747          0      22019    2020-03-01       West  L.A. Lakers  59
# 1  1610612743          0      22019    2020-03-01       West       Denver  60
# 2  1610612746          0      22019    2020-03-01       West  LA Clippers  60
# 3  1610612745          0      22019    2020-03-01       West      Houston  59
# 4  1610612762          0      22019    2020-03-01       West         Utah  59
#
#     W   L  W_PCT HOME_RECORD ROAD_RECORD
# 0  46  13  0.780        21-7        25-6
# 1  41  19  0.683        24-7       17-12
# 2  41  19  0.683        25-6       16-13
# 3  39  20  0.661        21-8       18-12
# 4  37  22  0.627        21-9       16-13

# %%
teams_df
# teams_df.shape
# teams_df['NICKNAME']
# Out:
#     LEAGUE_ID     TEAM_ID  MIN_YEAR  MAX_YEAR ABBREVIATION       NICKNAME  \
# 0           0  1610612737      1949      2019          ATL          Hawks
# 1           0  1610612738      1946      2019          BOS        Celtics
# 2           0  1610612740      2002      2019          NOP       Pelicans
# 3           0  1610612741      1966      2019          CHI          Bulls
# 4           0  1610612742      1980      2019          DAL      Mavericks
# 5           0  1610612743      1976      2019          DEN        Nuggets
# 6           0  1610612745      1967      2019          HOU        Rockets
# 7           0  1610612746      1970      2019          LAC       Clippers
# 8           0  1610612747      1948      2019          LAL         Lakers
# 9           0  1610612748      1988      2019          MIA           Heat
# 10          0  1610612749      1968      2019          MIL          Bucks
# 11          0  1610612750      1989      2019          MIN   Timberwolves
# ...

# %%
table = pd.read_html('https://nba168.pixnet.net/blog/post/32636640')[0]
table.dropna(axis=0, how='any', inplace=True)
table.shape
# Out:
# (30, 3)

# %%
table.reset_index(inplace=True)

# %%
table.drop(['index'], axis=1,inplace=True)
#

# %%
table.columns=['chinese name','nickname','full name']
table['nickname']
teams_df['ABBREVIATION']
# Out:
# 0     ATL
# 1     BOS
# 2     NOP
# 3     CHI
# 4     DAL
# 5     DEN
# 6     HOU
# 7     LAC
# 8     LAL
# 9     MIA
# 10    MIL
# 11    MIN
# 12    BKN
# 13    NYK
# 14    ORL
# 15    IND
# 16    PHI
# 17    PHX
# 18    POR
# 19    SAC
# 20    SAS
# 21    OKC
# 22    TOR
# 23    UTA
# 24    MEM
# 25    WAS
# 26    DET
# 27    CHA
# 28    CLE
# 29    GSW
# Name: ABBREVIATION, dtype: object

# %%
list(set(table['nickname'])-set(teams_df['ABBREVIATION']))
# Out:
# ['NJ', 'PHO', 'NY', 'GS', 'NO', 'SEA']

# %%
searchList = list(set(teams_df['ABBREVIATION'])-set(table['nickname']))

# %%
table['nickname'].isin(list(set(table['nickname'])-set(teams_df['ABBREVIATION'])))
# Out:
# 0     False
# 1      True
# 2      True
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18     True
# 19    False
# 20    False
# 21    False
# 22    False
# 23     True
# 24    False
# 25     True
# 26    False
# 27    False
# 28     True
# 29    False
# Name: nickname, dtype: bool

# %%
table=table[~table['nickname'].isin(list(set(table['nickname'])-set(teams_df['ABBREVIATION'])))]
table.reset_index(inplace=True)

# %%
table
# Out:
#     index chinese name nickname               full name
# 0       0      波士頓塞爾蒂克      BOS          Boston Celtics
# 1       3        費城76人      PHI      Philadelphia 76ers
# 2       4        多倫多暴龍      TOR         Toronto Raptors
# 3       5        芝加哥公牛      CHI           Chicago Bulls
# 4       6       克里夫蘭騎士      CLE     Cleveland Cavaliers
# 5       7        底特律活塞      DET         Detroit Pistons
# 6       8       印地安那溜馬      IND          Indiana Pacers
# 7       9       密爾瓦基公鹿      MIL         Milwaukee Bucks
# 8      10       亞特蘭大老鷹      ATL           Atlanta Hawks
# 9      11        夏洛特山貓      CHA       Charlotte Bobcats
# 10     12        邁阿密熱火      MIA              Miami Heat
# 11     13        奧蘭多魔術      ORL           Orlando Magic
# 12     14        華盛頓巫師      WAS      Washington Wizards
# 13     15        達拉斯小牛      DAL        Dallas Mavericks
# 14     16        休士頓火箭      HOU         Houston Rockets
# 15     17        孟斐斯灰熊      MEM       Memphis Grizzlies
# ...

# %%
table.drop(['index'], axis=1,inplace=True)

# %%
table
# Out:
#    chinese name nickname               full name
# 0       波士頓塞爾蒂克      BOS          Boston Celtics
# 1         費城76人      PHI      Philadelphia 76ers
# 2         多倫多暴龍      TOR         Toronto Raptors
# 3         芝加哥公牛      CHI           Chicago Bulls
# 4        克里夫蘭騎士      CLE     Cleveland Cavaliers
# 5         底特律活塞      DET         Detroit Pistons
# 6        印地安那溜馬      IND          Indiana Pacers
# 7        密爾瓦基公鹿      MIL         Milwaukee Bucks
# 8        亞特蘭大老鷹      ATL           Atlanta Hawks
# 9         夏洛特山貓      CHA       Charlotte Bobcats
# 10        邁阿密熱火      MIA              Miami Heat
# 11        奧蘭多魔術      ORL           Orlando Magic
# 12        華盛頓巫師      WAS      Washington Wizards
# 13        達拉斯小牛      DAL        Dallas Mavericks
# 14        休士頓火箭      HOU         Houston Rockets
# 15        孟斐斯灰熊      MEM       Memphis Grizzlies
# 16      聖安東尼奧馬刺      SAS       San Antonio Spurs
# 17         丹佛金塊      DEN          Denver Nuggets
# ...

# %%
searchList
# Out:
# ['PHX', 'GSW', 'NYK', 'BKN', 'NOP', 'OKC']

# %%
searchListAll =[{'chinese name':'布魯克林籃網','nickname':'BKN','full name':"Brooklyn Nets"},
 {'chinese name':'俄克拉荷馬城雷霆','nickname':'OKC','full name':'Oklahoma City Thunder'},
 {'chinese name':'紐奧良鵜鶘','nickname':'NOP','full name':'New Orleans Pelicans'},
 {'chinese name':'紐約尼克','nickname':'NYK','full name':'New York Knicks'},
 {'chinese name':'金州勇士','nickname':'GSW','full name':'Golden State Warriors'},
 {'chinese name':'鳳凰城太陽','nickname':'PHX','full name':'Phoenix Suns'}]


for item in searchListAll:
    
    table= table.append(item, ignore_index=True)

# %%
# table.to_csv('./data/team_name_details.csv')

# %%
def getChineseName(x):
    return table.loc[table['nickname']==x,'chinese name'].values[0]
    

ans = getChineseName(x='GSW')
ans
# Out:
# '金州勇士'

# %%
teams_df['CHINESE'] = teams_df['ABBREVIATION'].apply(lambda x: getChineseName(x))

# %%
teams_df
# Out:
#     LEAGUE_ID     TEAM_ID  MIN_YEAR  MAX_YEAR ABBREVIATION       NICKNAME  \
# 0           0  1610612737      1949      2019          ATL          Hawks
# 1           0  1610612738      1946      2019          BOS        Celtics
# 2           0  1610612740      2002      2019          NOP       Pelicans
# 3           0  1610612741      1966      2019          CHI          Bulls
# 4           0  1610612742      1980      2019          DAL      Mavericks
# 5           0  1610612743      1976      2019          DEN        Nuggets
# 6           0  1610612745      1967      2019          HOU        Rockets
# 7           0  1610612746      1970      2019          LAC       Clippers
# 8           0  1610612747      1948      2019          LAL         Lakers
# 9           0  1610612748      1988      2019          MIA           Heat
# 10          0  1610612749      1968      2019          MIL          Bucks
# 11          0  1610612750      1989      2019          MIN   Timberwolves
# ...

# %%
chineseDict = dict(zip(teams_df['ABBREVIATION'],teams_df['CHINESE']))
chineseDict
# Out:
# {'ATL': '亞特蘭大老鷹',
#  'BOS': '波士頓塞爾蒂克',
#  'NOP': '紐奧良鵜鶘',
#  'CHI': '芝加哥公牛',
#  'DAL': '達拉斯小牛',
#  'DEN': '丹佛金塊',
#  'HOU': '休士頓火箭',
#  'LAC': '洛杉磯快艇',
#  'LAL': '洛杉磯湖人',
#  'MIA': '邁阿密熱火',
#  'MIL': '密爾瓦基公鹿',
#  'MIN': '明尼蘇達灰狼',
#  'BKN': '布魯克林籃網',
#  'NYK': '紐約尼克',
#  'ORL': '奧蘭多魔術',
#  'IND': '印地安那溜馬',
#  'PHI': '費城76人',
#  'PHX': '鳳凰城太陽',
#  'POR': '波特蘭拓荒者',
#  'SAC': '沙加緬度國王',
#  'SAS': '聖安東尼奧馬刺',
#  'OKC': '俄克拉荷馬城雷霆',
#  'TOR': '多倫多暴龍',
#  'UTA': '猶他爵士',
#  'MEM': '孟斐斯灰熊',
#  'WAS': '華盛頓巫師',
#  'DET': '底特律活塞',
#  'CHA': '夏洛特山貓',
#  'CLE': '克里夫蘭騎士',
#  'GSW': '金州勇士'}
