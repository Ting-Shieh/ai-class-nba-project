# %%
import pandas as pd

# %%
games_df=pd.read_csv('./data/games.csv')  #主場和客場的總體數據
games_details_df=pd.read_csv('./data/games_details.csv')# 有上場球員的比賽詳細數據
players_df=pd.read_csv('./data/players.csv')# PLAYER_NAME|TEAM_ID|PLAYER_ID|SEASON
# TEAM_ID| LEAGUE_ID| SEASON_ID| STANDINGSDATE| CONFERENCE| TEAM| G| W| L| W_PCT| HOME_RECORD| ROAD_RECORD
ranking_df=pd.read_csv('./data/ranking.csv')
teams_df=pd.read_csv('./data/teams.csv') 
teams_name_df=pd.read_csv('./data/team_name_details.csv').drop(['Unnamed: 0'],axis=1)

# %%
sasId = teams_df.loc[teams_df['ABBREVIATION']=='SAS','TEAM_ID'].values[0]

# %%
# 兩年球員差異
def playerDiff(new,old):
    return list(set(old).difference(set(new))) 
# playerdiff_list = playerDiff(players2019,players2018)

# %%
all_year_list = players_df.loc[players_df['TEAM_ID']==sasId,'SEASON'].unique()

# %%
playerYesrDict = {}
for year in all_year_list:
    playerYesrDict['player'+str(year)] = list(players_df.loc[(players_df['TEAM_ID']==sasId)&(players_df['SEASON']==year),'PLAYER_ID'].unique())

# %%
# 每年的球員名單
playerYesrDict
# Out:
# {'player2019': [201942,
#   200752,
#   1627751,
#   1628401,
#   1627854,
#   1627749,
#   201988,
#   1626168,
#   1629234,
#   201158,
#   1629022,
#   201960,
#   1629002,
#   200746,
#   1629640,
#   1629683,
#   1629677,
#   1629756,
#   1629664],
#  'player2018': [201942,
#   200746,
#   1627751,
#   1627854,
#   1628401,
#   200752,
#   201988,
#   201158,
#   202722,
#   201967,
#   202700,
#   202347,
#   1629022,
#   1629234,
#   1629002,
#   2200,
#   1627855,
#   203910,
#   203962,
#   1627749,
#   1628417],
#  'player2017': [201980,
#   200752,
#   200746,
#   201988,
#   1627749,
#   1938,
#   203937,
#   2200,
#   2225,
#   202722,
#   1627854,
#   203530,
#   1628401,
#   203464,
#   1626199,
#   1627856,
#   202695,
#   1628578,
#   1628506],
#  'player2016': [203613,
#   1938,
#   200746,
#   201980,
#   201988,
#   203937,
#   1627749,
#   1627854,
#   2200,
#   203473,
#   202722,
#   201202,
#   202695,
#   101135,
#   2225,
#   1627879,
#   1627868,
#   1627853,
#   203520],
#  'player2015': [202695,
#   200746,
#   1495,
#   201980,
#   2225,
#   201988,
#   2561,
#   1938,
#   203937,
#   2755,
#   1626246,
#   1889,
#   2564,
#   203613,
#   2588,
#   2446,
#   203492,
#   202130,
#   202690,
#   1626208,
#   203472,
#   1626304],
#  'player2014': [202695,
#   1495,
#   201168,
#   201980,
#   2225,
#   2564,
#   1938,
#   201988,
#   201158,
#   2588,
#   201965,
#   203382,
#   202709,
#   203937,
#   202130,
#   203210,
#   201948,
#   203955,
#   204027],
#  'player2013': [202695,
#   1495,
#   2564,
#   201980,
#   2225,
#   1938,
#   201168,
#   201988,
#   2588,
#   201158,
#   201965,
#   202709,
#   203382,
#   201948,
#   202345,
#   200769,
#   201986,
#   201785,
#   202952,
#   203327,
#   203587,
#   1894,
#   202408,
#   203509],
#  'player2012': [202695,
#   1938,
#   1495,
#   201980,
#   2225,
#   202390,
#   2564,
#   201168,
#   202709,
#   201971,
#   2588,
#   201986,
#   1503,
#   201988,
#   203382,
#   1536,
#   202341,
#   2694,
#   201974,
#   2201,
#   203178,
#   203174],
#  'player2011': [202695,
#   1495,
#   2564,
#   1938,
#   2225,
#   1536,
#   201168,
#   202390,
#   201980,
#   201971,
#   202341,
#   2588,
#   201988,
#   202709,
#   201182,
#   202458,
#   201286,
#   2210,
#   2551,
#   202952,
#   101113,
#   202912,
#   202371,
#   202545,
#   200852,
#   201230,
#   200779],
#  'player2010': [2210,
#   1495,
#   686,
#   1938,
#   2225,
#   201588,
#   202390,
#   201168,
#   2588,
#   201980,
#   201971,
#   200779,
#   202341,
#   200809,
#   201785,
#   202082,
#   2137,
#   202087,
#   202066,
#   2250,
#   201998,
#   201620,
#   202408,
#   2632],
#  'player2009': [2210,
#   686,
#   1495,
#   2225,
#   1938,
#   201588,
#   2588,
#   201971,
#   2427,
#   2586,
#   101133,
#   202066,
#   201612,
#   202132,
#   714,
#   689,
#   2409,
#   201998,
#   201173,
#   101204]}

# %%
# games_details_df.loc[games_details_df['TEAM_ID']==sasId]
all_year_list[0:6]
# Out:
# array([2019, 2018, 2017, 2016, 2015, 2014], dtype=int64)

# %%
sas_games_df = games_df.loc[(games_df['HOME_TEAM_ID']==sasId)|(games_df['VISITOR_TEAM_ID']==sasId)]

sasYearDF = {}

for year in all_year_list[0:6]:
    
    sasYearDF[str(year)+'df'] = sas_games_df.loc[(sas_games_df['SEASON'].isin(all_year_list[0:6]))&(sas_games_df['SEASON']==year)]

# %%
# 每年的sas比賽場次名單
sasYearDF['2019df']
# Out:
#       GAME_DATE_EST   GAME_ID GAME_STATUS_TEXT  HOME_TEAM_ID  VISITOR_TEAM_ID  \
# 13       2020-02-29  21900893            Final    1610612759       1610612753
# 35       2020-02-26  21900869            Final    1610612759       1610612742
# 57       2020-02-23  21900846            Final    1610612760       1610612759
# 73       2020-02-21  21900832            Final    1610612762       1610612759
# 98       2020-02-11  21900805            Final    1610612760       1610612759
# ...             ...       ...              ...           ...              ...
# 16135    2019-10-18  11900078            Final    1610612759       1610612763
# 16144    2019-10-16  11900064            Final    1610612745       1610612759
# 16158    2019-10-13  11900048            Final    1610612759       1610612740
# 16182    2019-10-08  11900019            Final    1610612748       1610612759
# 16193    2019-10-05  11900007            Final    1610612759       1610612753
#
#        SEASON  TEAM_ID_home  PTS_home  FG_PCT_home  FT_PCT_home  ...  \
# 13       2019    1610612759     114.0        0.524        0.750  ...
# 35       2019    1610612759     103.0        0.424        0.737  ...
# 57       2019    1610612760     131.0        0.575        0.875  ...
# 73       2019    1610612762     104.0        0.427        0.846  ...
# 98       2019    1610612760     106.0        0.459        0.810  ...
# ...       ...           ...       ...          ...          ...  ...
# 16135    2019    1610612759     104.0        0.396        0.643  ...
# 16144    2019    1610612745     114.0        0.438        0.682  ...
# 16158    2019    1610612759     114.0        0.463        0.838  ...
# 16182    2019    1610612748     107.0        0.461        0.810  ...
# 16193    2019    1610612759      89.0        0.388        0.750  ...
#
#        AST_home  REB_home  TEAM_ID_away  PTS_away  FG_PCT_away  FT_PCT_away  \
# 13         28.0      31.0    1610612753     113.0        0.488        0.696
# 35         22.0      55.0    1610612742     109.0        0.419        0.667
# 57         28.0      54.0    1610612759     103.0        0.369        0.842
# 73         25.0      47.0    1610612759     113.0        0.440        0.885
# 98         19.0      35.0    1610612759     114.0        0.488        0.926
# ...         ...       ...           ...       ...          ...          ...
# 16135      26.0      63.0    1610612763      91.0        0.344        0.769
# 16144      20.0      46.0    1610612759     128.0        0.571        0.636
# 16158      24.0      38.0    1610612740     123.0        0.489        0.767
# 16182      25.0      49.0    1610612759      89.0        0.400        0.808
# 16193      22.0      40.0    1610612753     125.0        0.526        0.714
#
#        FG3_PCT_away  AST_away  REB_away  HOME_TEAM_WINS
#
#
#        FG3_PCT_away  AST_away  REB_away  HOME_TEAM_WINS
# 13            0.405      28.0      41.0               1
# 172           0.278      29.0      37.0               1
# 191           0.368      18.0      43.0               1
# 262           0.294      23.0      47.0               1
# 360           0.333      24.0      38.0               1
# 402           0.444      31.0      44.0               1
# 424           0.333      20.0      40.0               1
# 483           0.194      16.0      47.0               1
# 579           0.265      19.0      52.0               1
# 599           0.294      22.0      60.0               1
# 15861         0.364      23.0      48.0               1
# 16017         0.476      26.0      31.0               1
# 16087         0.303      19.0      49.0               1
# 16103         0.471      30.0      41.0               1
# 16125         0.333      24.0      39.0               1
# 16135         0.200      20.0      57.0               1
#
# [16 rows x 21 columns]

# %%
# sas 客座 贏
sasYearDF['2019df'].loc[(sasYearDF['2019df']['TEAM_ID_away']==sasId)&(sasYearDF['2019df']['HOME_TEAM_WINS']==0)]
# Out:
#       GAME_DATE_EST   GAME_ID GAME_STATUS_TEXT  HOME_TEAM_ID  VISITOR_TEAM_ID  \
# 73       2020-02-21  21900832            Final    1610612762       1610612759
# 98       2020-02-11  21900805            Final    1610612760       1610612759
# 245      2020-01-22  21900663            Final    1610612740       1610612759
# 259      2020-01-20  21900650            Final    1610612756       1610612759
# 313      2020-01-12  21900587            Final    1610612761       1610612759
# 338      2020-01-08  21900554            Final    1610612738       1610612759
# 452      2019-12-23  21900450            Final    1610612763       1610612759
# 513      2019-12-14  21900380            Final    1610612756       1610612759
# 15901    2019-11-23  21900229            Final    1610612752       1610612759
# 16062    2019-11-01  21900076            Final    1610612744       1610612759
# 16144    2019-10-16  11900064            Final    1610612745       1610612759
#
#        SEASON  TEAM_ID_home  PTS_home  FG_PCT_home  FT_PCT_home  ...  \
# 73       2019    1610612762     104.0        0.427        0.846  ...
# 98       2019    1610612760     106.0        0.459        0.810  ...
# 245      2019    1610612740     117.0        0.464        0.781  ...
# 259      2019    1610612756     118.0        0.525        0.867  ...
# 313      2019    1610612761     104.0        0.406        0.818  ...
# 338      2019    1610612738     114.0        0.416        0.900  ...
# 452      2019    1610612763     115.0        0.469        0.625  ...
# 513      2019    1610612756     119.0        0.437        0.731  ...
# 15901    2019    1610612752     104.0        0.430        0.600  ...
# 16062    2019    1610612744     110.0        0.464        0.905  ...
# 16144    2019    1610612745     114.0        0.438        0.682  ...
#
#        AST_home  REB_home  TEAM_ID_away  PTS_away  FG_PCT_away  FT_PCT_away  \
# 73         25.0      47.0    1610612759     113.0        0.440        0.885
# 98         19.0      35.0    1610612759     114.0        0.488        0.926
# 245        26.0      41.0    1610612759     121.0        0.506        0.800
# 259        26.0      43.0    1610612759     120.0        0.494        0.773
# 313        30.0      45.0    1610612759     105.0        0.437        0.733
# 338        26.0      39.0    1610612759     129.0        0.552        0.923
# 452        28.0      35.0    1610612759     145.0        0.674        0.714
# 513        29.0      59.0    1610612759     121.0        0.415        0.735
# 15901      30.0      37.0    1610612759     111.0        0.533        0.679
# 16062      25.0      39.0    1610612759     127.0        0.473        0.867
# 16144      20.0      46.0    1610612759     128.0        0.571        0.636
#
#        FG3_PCT_away  AST_away  REB_away  HOME_TEAM_WINS
# 73            0.500      22.0      48.0               0
# 98            0.280      20.0      46.0               0
# 245           0.407      17.0      44.0               0
# 259           0.548      30.0      31.0               0
# 313           0.219      24.0      51.0               0
# 338           0.310      28.0      49.0               0
# 452           0.625      36.0      46.0               0
# 513           0.267      23.0      62.0               0
# 15901         0.522      26.0      47.0               0
# 16062         0.371      23.0      52.0               0
# 16144         0.370      29.0      43.0               0
#
# [11 rows x 21 columns]
